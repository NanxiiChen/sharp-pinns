# %%
import os 
os.chdir("../")

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams as rc

import torch
# font manager
# add font by otf file
from matplotlib import font_manager as fm
fm.fontManager.addfont("./eval/fonts/Palatino Linotype/palatinolinotype_roman.ttf")




configs = {
    'xtick.direction': 'in',
    'ytick.direction': 'in',
    # 'font.sans-serif': ['Microsoft YaHei', 'SimHei', 'Arial', 'Liberation Sans', 'sans-serif'],
    'font.sans-serif': ['Palatino Linotype', 'Microsoft YaHei', 'SimHei', 'Arial', 'Liberation Sans', 'sans-serif'],
    'axes.grid': True,
    'grid.alpha': 0.5,
    'grid.linestyle': '--',
    'mathtext.fontset': "cm",
    # 'mathtext.cal':"asana math",
    "font.size": 18,
    # 'axes.labelsize': 'large',
    # 'axes.labelpad': 8.0,
    # 'xtick.major.pad': 9.0,
}
rc.update(configs)
# save_root = "./figures/"

# %%
model_dir = "/root/tf-logs/3d-2pits-baseline-1128-128_4/model-525.pt"

import torch
import pf_pinn as pfp
from matplotlib import gridspec
net = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False
)
net.model.model.act = torch.nn.Tanh()

net.to(net.device)
net.load_state_dict(torch.load(model_dir))
net
# Out:
# PFPINN(
#   (embedding): SpatialTemporalFourierEmbedding()
#   (model): PFEncodedPINN(
#     (model): ModifiedMLP(
#       (gate_layer_1): Linear(in_features=256, out_features=128, bias=True)
#       (gate_layer_2): Linear(in_features=256, out_features=128, bias=True)
#       (hidden_layers): ModuleList(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): Linear(in_features=128, out_features=128, bias=True)
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (out_layer): Linear(in_features=128, out_features=2, bias=True)
#       (act): Tanh()
#     )
#   )
# )

# %%
ts = [0.000, 1.311, 3.938, 6.565, 9.521]

mesh_points = np.load("./data/3d-2pits/mesh_points.npy") * 1e4
mse = 0

filter_ = np.where(
            (mesh_points[:, 0] >= -0.6) &
            (mesh_points[:, 0] <= 0.6) &
            (mesh_points[:, 1] >= -0.3) &
            (mesh_points[:, 1] <= 0.3) &
            (mesh_points[:, 2] >= 0) &
            (mesh_points[:, 2] <= 0.3)
        )[0]
mesh_points = mesh_points[filter_]

fig, axes = plt.subplots(2, len(ts), figsize=(5*len(ts), 10), 
                                 subplot_kw={"projection": "3d",
                                             "aspect": "auto",
                                             "box_aspect": (4, 2, 1),})
mesh_tensor = torch.from_numpy(mesh_points).float()
diffs = []
for idx, tic in enumerate(ts):
    tic_tensor = torch.ones(mesh_tensor.shape[0], 1)\
                .view(-1, 1) * tic * 1e-1
    geotime = torch.cat([mesh_tensor, tic_tensor], dim=1).to(net.device)
    with torch.no_grad():
        sol = net.net_u(geotime).detach().cpu().numpy()
        
    ax = axes[0, idx]
    idx_interface_sol = np.where((sol[:, 0] > 0.05) & (sol[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_sol, 0], mesh_points[idx_interface_sol, 1],
                mesh_points[idx_interface_sol, 2], c=sol[idx_interface_sol, 0],
                cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_sol, 0]**2 \
        + mesh_points[idx_interface_sol, 1]**2 \
        + mesh_points[idx_interface_sol, 2]**2) ** 0.5
    )
    ax.set_title(f"pred t = {tic:.3f} s")
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.6, 0.6), ylim=(-0.3, 0.3), zlim=(0.3, 0.))
    
    ax = axes[1, idx]
    truth = np.load("./data/3d-2pits/sol-" + f"{tic:.3f}" + ".npy")[filter_]
    diff = np.abs(sol[:, 0] - truth[:, 0])
    diffs.append(diff)
    idx_interface_truth = np.where((truth[:, 0] > 0.05) & (truth[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_truth, 0], mesh_points[idx_interface_truth, 1],
                    mesh_points[idx_interface_truth, 2], c=truth[idx_interface_truth, 0],
                    cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_truth, 0]**2 \
        + mesh_points[idx_interface_truth, 1]**2 \
        + mesh_points[idx_interface_truth, 2]**2) ** 0.5
    )
    ax.set_title(f"ref t = {tic:.3f} s\n error = {np.mean(diff):.3e}")
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.6, 0.6), ylim=(-0.3, 0.3), zlim=(0.3, 0.))

# add colorbar
cbar_ax = fig.add_axes([0.92, 0.15, 0.01, 0.7])
cbar = fig.colorbar(axes[0, 0].collections[0], cax=cbar_ax)

diffs = np.array(diffs)
print(f"max diff = {np.max(diffs):.3e}")
print(f"mean diff = {np.mean(diffs):.3e}")
plt.savefig("out.png", dpi=300, bbox_inches="tight")
# Out:
# /tmp/ipykernel_938/3987370825.py:64: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = fig.colorbar(axes[0, 0].collections[0], cax=cbar_ax)
# max diff = 5.686e-01
# mean diff = 1.755e-02

# %%
rc.update(configs)
ts = [0.000, 1.311, 3.938, 6.565, 9.521]

mesh_points = np.load("./data/3d-2pits/mesh_points.npy") * 1e4
mse = 0

filter_ = np.where(
            (mesh_points[:, 0] >= -0.6) &
            (mesh_points[:, 0] <= 0.6) &
            (mesh_points[:, 1] >= -0.3) &
            (mesh_points[:, 1] <= 0.3) &
            (mesh_points[:, 2] >= 0) &
            (mesh_points[:, 2] <= 0.3)
        )[0]
mesh_points = mesh_points[filter_]

subplot_kw = {"projection": "3d",
            # "aspect": "auto",
            "box_aspect": (4, 2, 1),}
# fig, axes = plt.subplots(2, len(ts), figsize=(5*len(ts), 10), 
#                                  subplot_kw={"projection": "3d",
#                                              "aspect": "auto",
#                                              "box_aspect": (1, 1, 0.5),})
mesh_tensor = torch.from_numpy(mesh_points).float()
diffs = []
for idx, tic in enumerate(ts):
    
    fig = plt.figure(figsize=(20, 4.5))
    fig.tight_layout()

    gs = gridspec.GridSpec(1, 6, width_ratios=[1, 0.05, 1, 0.05, 1, 0.05])
    
    
    tic_tensor = torch.ones(mesh_tensor.shape[0], 1)\
                .view(-1, 1) * tic * 1e-1
    geotime = torch.cat([mesh_tensor, tic_tensor], dim=1).to(net.device)
    with torch.no_grad():
        sol = net.net_u(geotime).detach().cpu().numpy()
        
    ax = fig.add_subplot(gs[0], **subplot_kw)
    
    idx_interface_sol = np.where((sol[:, 0] > 0.05) & (sol[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_sol, 0], mesh_points[idx_interface_sol, 1],
                mesh_points[idx_interface_sol, 2], c=sol[idx_interface_sol, 0],
                cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_sol, 0]**2 \
        + mesh_points[idx_interface_sol, 1]**2 \
        + mesh_points[idx_interface_sol, 2]**2) ** 0.5
    )
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),
           title=r"PINN solution $\hat\phi$" + " at "+ f"{tic:.3f} s",)
    #        xlabel="x " + r"$\mathrm{(\mu m)}$",
    #        ylabel="y " + r"$\mathrm{(\mu m)}$",
    #        zlabel="z " + r"$\mathrm{(\mu m)}$")
    # ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x*1e2:.0f}'))
    # ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x*1e2:.0f}'))
    # ax.zaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x*1e2:.0f}'))
    # ax.xaxis.labelpad = 20
    # ax.yaxis.labelpad = 20
    
    
    
    ax_bar = fig.add_subplot(gs[1])
    fig.colorbar(ax.collections[0], cax=ax_bar)
    ax_bar.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x:.2f}'))
    pos = ax_bar.get_position()
    ax_bar.set_position([pos.x0 - 0.02, pos.y0+pos.height*0.25, pos.width, pos.height*0.6])
    ax_bar.set_title(r"$\phi$", loc="center")
    
    ax = fig.add_subplot(gs[2], **subplot_kw)
    truth = np.load("./data/3d-2pits/sol-" + f"{tic:.3f}" + ".npy")[filter_]
    diff = np.abs(sol[:, 0] - truth[:, 0])
    diffs.append(diff)
    idx_interface_truth = np.where((truth[:, 0] > 0.05) & (truth[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_truth, 0], mesh_points[idx_interface_truth, 1],
                    mesh_points[idx_interface_truth, 2], c=truth[idx_interface_truth, 0],
                    cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_truth, 0]**2 \
        + mesh_points[idx_interface_truth, 1]**2 \
        + mesh_points[idx_interface_truth, 2]**2) ** 0.5
    )
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),
           title=r"Reference solution $\phi_{\mathrm{ref}}$" + " at "+ f"{tic:.3f} s")
    
    ax_bar = fig.add_subplot(gs[3])
    fig.colorbar(ax.collections[0], cax=ax_bar)
    ax_bar.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x:.2f}'))
    pos = ax_bar.get_position()
    ax_bar.set_position([pos.x0 - 0.02, pos.y0+pos.height*0.25, pos.width, pos.height*0.6])
    ax_bar.set_title(r"$\phi_{\mathrm{ref}}$", loc="center")
    
    ax = fig.add_subplot(gs[4], **subplot_kw)
    diff = np.abs(sol[:, 0] - truth[:, 0])
    idx_interface_diff = np.where((diff > 0.05))[0]
    ax.scatter(mesh_points[idx_interface_diff, 0], mesh_points[idx_interface_diff, 1],
                    mesh_points[idx_interface_diff, 2], c=diff[idx_interface_diff],
                    cmap="coolwarm", label="phi",)
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),
           title=r"Absolute error $|\hat\phi - \phi_{\mathrm{ref}}|$" + " at "+ f"{tic:.3f} s" )
    
    ax_bar = fig.add_subplot(gs[5])
    fig.colorbar(ax.collections[0], cax=ax_bar)    
    ax_bar.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x:.2f}'))
    pos = ax_bar.get_position()
    ax_bar.set_position([pos.x0 - 0.02, pos.y0+pos.height*0.25, pos.width, pos.height*0.6])
    ax_bar.set_title(r"$|\hat\phi - \phi_{\mathrm{ref}}|$", loc="center")
    # plt.savefig("./figures/3d-2pits-phi-fields" + f"-{idx}" + ".png", dpi=300, bbox_inches="tight")
    # plt.subplots_adjust(left=0.00, right=1, top=1, bottom=0.00,
    #                     wspace=0.1, hspace=0.05)
# # add colorbar
# cbar_ax = fig.add_axes([0.92, 0.15, 0.01, 0.7])
# cbar = fig.colorbar(axes[0, 0].collections[0], cax=cbar_ax)

diffs = np.array(diffs)
print(f"max diff = {np.max(diffs):.3e}")
print(f"mean diff = {np.mean(diffs):.3e}")

# img_names = [f"./figures/3d-2pits-phi-fields-{idx}.png" for idx in range(len(ts))]
# from PIL import Image
# import os
# # 裁切掉图片下半部分的白边
# for img_name in img_names:
#     im = Image.open(img_name)
#     w, h = im.size
#     im = im.crop((0, 0, w, h-250))
#     im.save(img_name)
# Out:
# /tmp/ipykernel_938/1973780598.py:67: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(ax.collections[0], cax=ax_bar)
# /tmp/ipykernel_938/1973780598.py:92: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(ax.collections[0], cax=ax_bar)
# /tmp/ipykernel_938/1973780598.py:110: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(ax.collections[0], cax=ax_bar)
# max diff = 5.686e-01
# mean diff = 1.755e-02

# %%
def format_with_scitific(x, prefix="L^2\; \\mathrm{error} = "):
    # e.g. 1.234\times 10^{-3}
    x = f"{x:.3e}"
    x = x.split("e")
    return prefix + f"{x[0]}\\times 10^{{{int(x[1])}}}"

# %%
rc.update(configs)
ts = [0.000, 1.311, 3.938, 9.521]

mesh_points = np.load("./data/3d-2pits/mesh_points.npy") * 1e4
mse = 0


filter_ = np.where(
            (mesh_points[:, 0] >= -0.6) &
            (mesh_points[:, 0] <= 0.6) &
            (mesh_points[:, 1] >= -0.3) &
            (mesh_points[:, 1] <= 0.3) &
            (mesh_points[:, 2] >= 0) &
            (mesh_points[:, 2] <= 0.3)
        )[0]
mesh_points = mesh_points[filter_]

subplot_kw = {"projection": "3d",
            "box_aspect": (4, 2, 1),}
# fig, axes = plt.subplots(2, len(ts), figsize=(5*len(ts), 10), 
#                                  subplot_kw={"projection": "3d",
#                                              "aspect": "auto",
#                                              "box_aspect": (1, 1, 0.5),})

mesh_tensor = torch.from_numpy(mesh_points).float()
diffs = []

fig = plt.figure(figsize=(9, 2.*len(ts)))
gs = gridspec.GridSpec(len(ts)+1, 5, width_ratios=[0.05, 1, 1, 1, 0.05], height_ratios=[0.1, 1, 1, 1, 1],
                       top=1, bottom=0, left=0, right=1,)
col_names = [" ", "PINN Solution $\hat\phi$", "Reference Solution $\phi_{\mathrm{ref}}$", "Absolute Error $|\hat\phi - \phi_{\mathrm{ref}}|$"]
for idx, col_name in enumerate(col_names):
    ax = fig.add_subplot(gs[0, idx])
    ax.text(0.5, 0., col_name, fontsize=18,
            verticalalignment='bottom', horizontalalignment='center')
    ax.set_axis_off()
    
for idx, tic in enumerate(ts):
    
    ax = fig.add_subplot(gs[idx+1, 0])
    # text: t = 1.111s , fontsize=18, rotation=90
    ax.text(1.0, 0.5, f"t = {tic:.3f} s", fontsize=18, rotation=90, transform=ax.transAxes,
            verticalalignment='center', horizontalalignment='right')
    ax.set_axis_off()
    
    
    tic_tensor = torch.ones(mesh_tensor.shape[0], 1)\
                .view(-1, 1) * tic * 1e-1
    geotime = torch.cat([mesh_tensor, tic_tensor], dim=1).to(net.device)
    with torch.no_grad():
        sol = net.net_u(geotime).detach().cpu().numpy()
        
    ax = fig.add_subplot(gs[idx+1, 1], **subplot_kw)
    idx_interface_sol = np.where((sol[:, 0] > 0.05) & (sol[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_sol, 0], mesh_points[idx_interface_sol, 1],
                mesh_points[idx_interface_sol, 2], c=sol[idx_interface_sol, 0],
                cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_sol, 0]**2 \
        + mesh_points[idx_interface_sol, 1]**2 \
        + mesh_points[idx_interface_sol, 2]**2) ** 0.5
    )
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),)
    
    ax = fig.add_subplot(gs[idx+1, 2], **subplot_kw)
    truth = np.load("./data/3d-2pits/sol-" + f"{tic:.3f}" + ".npy")[filter_]
    diff = np.abs(sol[:, 0] - truth[:, 0])
    diffs.append(diff)
    idx_interface_truth = np.where((truth[:, 0] > 0.05) & (truth[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_truth, 0], mesh_points[idx_interface_truth, 1],
                    mesh_points[idx_interface_truth, 2], c=truth[idx_interface_truth, 0],
                    cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_truth, 0]**2 \
        + mesh_points[idx_interface_truth, 1]**2 \
        + mesh_points[idx_interface_truth, 2]**2) ** 0.5
    )
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),)
    
    
    ax = fig.add_subplot(gs[idx+1, 3], **subplot_kw)
    diff = np.abs(sol[:, 0] - truth[:, 0])
    idx_interface_diff = np.where((diff > 0.05))[0]
    ax.scatter(mesh_points[idx_interface_diff, 0], mesh_points[idx_interface_diff, 1],
                    mesh_points[idx_interface_diff, 2], c=diff[idx_interface_diff],
                    cmap="coolwarm", label="phi",)
    ax.set_axis_off()
    ax.view_init(elev=30, azim=45)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),)
    
    ax.text2D(0.5, 0.01, "$" + format_with_scitific(np.mean(diff**2)) + "$", 
              fontsize=18, verticalalignment='bottom', horizontalalignment='center', transform=ax.transAxes)
    
    
    ax_bar = fig.add_subplot(gs[idx+1, 4],)
    cbar = fig.colorbar(ax.collections[0], cax=ax_bar)    
    ax_bar.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'{x:.2f}'))
    cbar.set_label(r'$|\hat\phi - \phi_{\mathrm{ref}}|$')
    # pos = ax_bar.get_position()
    # ax_bar.set_position([pos.x0 - 0.02, pos.y0+pos.height*0.25, pos.width, pos.height*0.6])
    # ax_bar.set_title(r"$|\hat\phi - \phi_{\mathrm{ref}}|$", loc="center")
plt.subplots_adjust(wspace=0.1, hspace=0.1)  
diffs = np.array(diffs)
print(f"max diff = {np.max(diffs):.3e}")
print(f"mean diff = {np.mean(diffs):.3e}")
# plt.savefig("./figures/3d-2pits-phi-fields.png", dpi=300, bbox_inches="tight")
# Out:
# /tmp/ipykernel_938/3293442048.py:100: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = fig.colorbar(ax.collections[0], cax=ax_bar)
# max diff = 5.686e-01
# mean diff = 1.644e-02

# %%
model_dir = "/root/tf-logs/3d-2pits-baseline-1128-128_4/model-525.pt"

import torch
import pf_pinn as pfp
from matplotlib import gridspec
net = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False
)
net.model.model.act = torch.nn.Tanh()

net.to(net.device)
net.load_state_dict(torch.load(model_dir))


net_no_stagger = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False
)
net_no_stagger.to(net_no_stagger.device)
net_no_stagger.load_state_dict(torch.load("/root/tf-logs/experiments/3d-2pits-nostagger-3/model-1000.pt"))

net_no_hardcons = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False, hard_constrain=False
)
net_no_hardcons.to(net_no_hardcons.device)
net_no_hardcons.load_state_dict(torch.load("/root/tf-logs/experiments/3d-2pits-nohardcons-3/model-1000.pt"))

net_no_modifiedmlp = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False, arch="mlp"
)
net_no_modifiedmlp.to(net_no_modifiedmlp.device)
net_no_modifiedmlp.load_state_dict(torch.load("/root/tf-logs/experiments/3d-2pits-nomodifiedmlp-3/model-1000.pt"))

net_no_ffe = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False, fourier_embedding=False
)
net_no_ffe.to(net_no_ffe.device)
net_no_ffe.load_state_dict(torch.load("/root/tf-logs/experiments/3d-2pits-noffe-2/model-1000.pt"))

net_plain = pfp.PFPINN(
    in_dim=256, hidden_dim=128, out_dim=2, layers=4,
    symmetrical_forward=False, fourier_embedding=False, arch="mlp", hard_constrain=False
)
net_plain.to(net_plain.device)
net_plain.load_state_dict(torch.load("/root/tf-logs/experiments/3d-2pits-plain/model-1000.pt"))
# Out:
# <All keys matched successfully>

# %%
rc.update(configs)
rc.update({"font.size": 14})
ts = [0.000, 1.311, 3.938, 9.521]

mesh_points = np.load("./data/3d-2pits/mesh_points.npy") * 1e4
mse = 0


filter_ = np.where(
            (mesh_points[:, 0] >= -0.6) &
            (mesh_points[:, 0] <= 0.6) &
            (mesh_points[:, 1] >= -0.3) &
            (mesh_points[:, 1] <= 0.3) &
            (mesh_points[:, 2] >= 0) &
            (mesh_points[:, 2] <= 0.3)
        )[0]
mesh_points = mesh_points[filter_]
subplot_kw = {"projection": "3d",
            "box_aspect": (4, 2, 1),}

mesh_tensor = torch.from_numpy(mesh_points).float()
diffs = []

fig = plt.figure(figsize=(12, 15))
gs = gridspec.GridSpec(7*2 + 1, 5, width_ratios=[0.1, 1, 1, 1, 1], height_ratios=[0.1,] + [1, 0.05]*7,)
model_panels = [net, net_no_stagger, net_no_hardcons, net_no_modifiedmlp, net_no_ffe,  net_plain]

row_names = ["Reference", "Proposed", "W/o Stagger", 
             "W/o Hard Cons", "W/o ModifiedMLP", "W/o Fourier",
             "Plain"]
for idx, row_name in enumerate(row_names):
    ax = fig.add_subplot(gs[idx*2+1, 0])
    ax.text(1, 0.5, row_name, fontsize=14, rotation=90, transform=ax.transAxes,
            verticalalignment='center', horizontalalignment='center')
    ax.set_axis_off()
    
    
    

for idx, tic in enumerate(ts):
    
    ax = fig.add_subplot(gs[0, idx+1])
    ax.text(0.5, 0., f"$t = {tic:.3f}\;" + "\mathrm{s}$", fontsize=18, transform=ax.transAxes,
            verticalalignment='bottom', horizontalalignment='center')
    ax.set_axis_off()
    
    ax = fig.add_subplot(gs[1, idx+1], **subplot_kw)
    truth = np.load("./data/3d-2pits/sol-" + f"{tic:.3f}" + ".npy")[filter_]
    diff = np.abs(sol[:, 0] - truth[:, 0])
    diffs.append(diff)
    idx_interface_truth = np.where((truth[:, 0] > 0.05) & (truth[:, 0] < 0.95))[0]
    ax.scatter(mesh_points[idx_interface_truth, 0], mesh_points[idx_interface_truth, 1],
                    mesh_points[idx_interface_truth, 2], c=truth[idx_interface_truth, 0],
                    cmap="coolwarm", label="phi", vmin=0, vmax=1)
    avg_depth = np.mean(
        (mesh_points[idx_interface_truth, 0]**2 \
        + mesh_points[idx_interface_truth, 1]**2 \
        + mesh_points[idx_interface_truth, 2]**2) ** 0.5
    )
    ax.set_axis_off()
    ax.view_init(elev=30, azim=120)
    ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),)
    
    tic_tensor = torch.ones(mesh_tensor.shape[0], 1)\
                .view(-1, 1) * tic * 1e-1
    geotime = torch.cat([mesh_tensor, tic_tensor], dim=1).to(net.device)
    
    for model_idx, model in enumerate(model_panels):
        with torch.no_grad():
            sol = model.net_u(geotime).detach().cpu().numpy()
        ax = fig.add_subplot(gs[model_idx*2+3, idx+1], **subplot_kw)
            
        idx_interface_sol = np.where((sol[:, 0] > 0.05) & (sol[:, 0] < 0.95))[0] 

        ax.scatter(mesh_points[idx_interface_sol, 0], mesh_points[idx_interface_sol, 1],
                    mesh_points[idx_interface_sol, 2], c=sol[idx_interface_sol, 0],
                    cmap="coolwarm", label="phi", vmin=0, vmax=1)
        avg_depth = np.mean(
            (mesh_points[idx_interface_sol, 0]**2 \
            + mesh_points[idx_interface_sol, 1]**2 \
            + mesh_points[idx_interface_sol, 2]**2) ** 0.5
        )
        ax.set_axis_off()
        ax.set(xlim=(-0.5, 0.5), ylim=(-0.25, 0.25), zlim=(0.25, 0.),)
        ax.view_init(elev=30, azim=120)
        
        diff = np.abs(sol[:, 0] - truth[:, 0])
        
        ax = fig.add_subplot(gs[model_idx*2+4, idx+1])
        # ax.text2D(0.5, 0.99, "$" + format_with_scitific(np.mean(diff**2)) + "$", 
        #       fontsize=18, verticalalignment='top', horizontalalignment='center', transform=ax.transAxes)
    
        ax.text(0.5, 0.5, "$" + format_with_scitific(np.mean(diff**2)) + "$",
                verticalalignment='center', horizontalalignment='center')
        ax.set_axis_off()

plt.subplots_adjust(wspace=0.1, hspace=0.1)  
plt.savefig("./figures/3d-2pits-phi-fields-comparison-all.png", dpi=300, bbox_inches="tight")
